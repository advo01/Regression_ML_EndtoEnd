# %%
import boto3
from pathlib import Path

# ---- Config ----



bucket = "ab-ml-regression"   # replace with your bucket name
region = "eu-north-1" 
AWS_ACCESS_KEY_ID = "AKIASICU3B7K6BDBYJP3"
AWS_SECRET_ACCESS_KEY = "qWGtn7RL+H8XNkJ+DP5USHRDIFsxAmmr6ib0T4sl"                # your AWS region

# Set project root as parent of the notebooks folder
PROJECT_ROOT = Path.cwd().parent
local_data_dir = PROJECT_ROOT / "data" / "processed"
local_model_dir = PROJECT_ROOT / "models"

s3 = boto3.client(
    "s3", 
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY, 
    region_name=region
    )

# ---- Helper function ----
def upload_file(local_path: Path, s3_key: str):
    if not local_path.exists():
        print(f"❌ File not found: {local_path}")
        return
    print(f"⬆️ Uploading {local_path} → s3://{bucket}/{s3_key}")
    s3.upload_file(str(local_path), bucket, s3_key)

# ---- Upload required datasets ----
upload_file(local_data_dir / "feature_engineered_holdout", "Processed/feature_engineered_holdout.csv")
upload_file(local_data_dir / "cleaning_holdout.csv", "Processed/cleaning_holdout.csv")
upload_file(local_data_dir / "feature_engineered_train.csv", "Processed/feature_engineered_train.csv")

# ---- Upload model ----
upload_file(local_model_dir / "xgb_best_model.pkl", "models/xgb_best_model.pkl")
# Out:
# ❌ File not found: /Users/advocateboitshepo/Documents/Machine Learning/Regression_ML_EndtoEnd/data/processed/feature_engineered_holdout
# ⬆️ Uploading /Users/advocateboitshepo/Documents/Machine Learning/Regression_ML_EndtoEnd/data/processed/cleaning_holdout.csv → s3://ab-ml-regression/Processed/cleaning_holdout.csv
# ⬆️ Uploading /Users/advocateboitshepo/Documents/Machine Learning/Regression_ML_EndtoEnd/data/processed/feature_engineered_train.csv → s3://ab-ml-regression/Processed/feature_engineered_train.csv
# ⬆️ Uploading /Users/advocateboitshepo/Documents/Machine Learning/Regression_ML_EndtoEnd/models/xgb_best_model.pkl → s3://ab-ml-regression/models/xgb_best_model.pkl
